# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
dataset = pd.read_csv("/Users/pawankumarkc/Documents/vscode_workspace/MLAlgo/datasets/German Credit Dataset.csv")
dataset.head()
# Out:
#   checking_balance  months_loan_duration credit_history               purpose  \
# 0           < 0 DM                     6       critical  furniture/appliances
# 1       1 - 200 DM                    48           good  furniture/appliances
# 2          unknown                    12       critical             education
# 3           < 0 DM                    42           good  furniture/appliances
# 4           < 0 DM                    24           poor                   car
#
#    amount savings_balance employment_duration  percent_of_income  \
# 0    1169         unknown           > 7 years                  4
# 1    5951        < 100 DM         1 - 4 years                  2
# 2    2096        < 100 DM         4 - 7 years                  2
# 3    7882        < 100 DM         4 - 7 years                  2
# 4    4870        < 100 DM         1 - 4 years                  3
#
#    years_at_residence  age other_credit housing  existing_loans_count  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   checking_balance      1000 non-null   object
#  1   months_loan_duration  1000 non-null   int64
#  2   credit_history        1000 non-null   object
#  3   purpose               1000 non-null   object
#  4   amount                1000 non-null   int64
#  5   savings_balance       1000 non-null   object
#  6   employment_duration   1000 non-null   object
#  7   percent_of_income     1000 non-null   int64
#  8   years_at_residence    1000 non-null   int64
#  9   age                   1000 non-null   int64
#  10  other_credit          1000 non-null   object
#  11  housing               1000 non-null   object
#  12  existing_loans_count  1000 non-null   int64
#  13  job                   1000 non-null   object
#  14  dependents            1000 non-null   int64
# ...

# %% [markdown]
# ## Part 1: Checking missing values

# %%
dataset.isnull().count()
# Out:
# checking_balance        1000
# months_loan_duration    1000
# credit_history          1000
# purpose                 1000
# amount                  1000
# savings_balance         1000
# employment_duration     1000
# percent_of_income       1000
# years_at_residence      1000
# age                     1000
# other_credit            1000
# housing                 1000
# existing_loans_count    1000
# job                     1000
# dependents              1000
# phone                   1000
# default                 1000
# dtype: int64

# %%
print(dataset['checking_balance'].unique())
# Out:
# ['< 0 DM' '1 - 200 DM' 'unknown' '> 200 DM']

# %%
dataset['checking_balance'].value_counts()
# Out:
# unknown       394
# < 0 DM        274
# 1 - 200 DM    269
# > 200 DM       63
# Name: checking_balance, dtype: int64

# %%
dataset.columns
# Out:
# Index(['checking_balance', 'months_loan_duration', 'credit_history', 'purpose',
#        'amount', 'savings_balance', 'employment_duration', 'percent_of_income',
#        'years_at_residence', 'age', 'other_credit', 'housing',
#        'existing_loans_count', 'job', 'dependents', 'phone', 'default'],
#       dtype='object')

# %%
for col in dataset:
    print(col)
    print(dataset[col].value_counts())
    print()
    print("************"*3)
# Out:
# checking_balance
# unknown       394
# < 0 DM        274
# 1 - 200 DM    269
# > 200 DM       63
# Name: checking_balance, dtype: int64
#
# ************************************
# months_loan_duration
# 24    184
# 12    179
# 18    113
# 36     83
# 6      75
# 15     64
# 9      49
# 48     48
# 30     40
# 21     30
# 10     28
# 60     13
# 27     13
# 42     11
# 11      9
# 20      8
# 8       7
# 4       6
# 45      5
# 7       5
# 39      5
# 14      4
# 13      4
# 33      3
# 28      3
# 54      2
# 16      2
# 22      2
# 47      1
# 5       1
# 26      1
# 72      1
# 40      1
# Name: months_loan_duration, dtype: int64
#
# ************************************
# credit_history
# good         530
# critical     293
# poor          88
# very good     49
# perfect       40
# Name: credit_history, dtype: int64
#
# ************************************
# purpose
# furniture/appliances    473
# car                     337
# business                 97
# ...
